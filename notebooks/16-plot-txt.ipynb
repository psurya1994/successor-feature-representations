# %%
import sys,os
import matplotlib.pyplot as plt
sys.path.append('../')
import numpy as np

# %%
import re
def log2list(filename):
    returns_train = []
    returns_test = []
    with open(filename, 'rb') as f:
        while True:
            line = f.readline()
            split = re.split('\s', str(line))
            if not line:
                break
            if('episodic_return_train' in split):
                returns_train.append(float(split[-1][:-3]))
            if('episodic_return_test' in split):
                returns_test.append(float(split[-1][:-10]))
                
    return returns_train, returns_test

# %%
# %ls ../storage/Mini*
# Out:
# ../storage/MiniGrid-Empty-5x5-v0--run-0-200908-104503.txt*
# ../storage/MiniGrid-Empty-5x5-v0--run-0-200908-112739.txt*

# %%
dsr_file = '../storage/MiniGrid-Empty-5x5-v0--run-0-200908-104503.txt'
train, test = log2list(dsr_file)

# %%
plt.plot(np.convolve(train, np.ones(11)/11))
